# %% [markdown]
# # Preprocessing Operations

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Import raw csv files

# %% [markdown]
# ### Laptop

# %%
sound_features_aedes_44_1 = pd.read_csv("/home/flo/Documents/Simplon/Formation/Cours/Proj_FinIntensif/Features_CSV/aedes_44_1.csv",sep=",")
sound_features_aedes_48 = pd.read_csv("/home/flo/Documents/Simplon/Formation/Cours/Proj_FinIntensif/Features_CSV/Aedes_48.csv",sep=",")
sound_features_culiseta_48 = pd.read_csv("/home/flo/Documents/Simplon/Formation/Cours/Proj_FinIntensif/Features_CSV/Culiseta_48.csv",sep=",")
sound_features_mixpipiensquinquefasciatus_48 = pd.read_csv("/home/flo/Documents/Simplon/Formation/Cours/Proj_FinIntensif/Features_CSV/MixPipiensQuinquefasciatus_48.csv",sep=",")
sound_features_quinquefasciatus_8 = pd.read_csv("/home/flo/Documents/Simplon/Formation/Cours/Proj_FinIntensif/Features_CSV/quinquefasciatus_8.csv",sep=",")
sound_features_quinquefasciatus_44_1 = pd.read_csv("/home/flo/Documents/Simplon/Formation/Cours/Proj_FinIntensif/Features_CSV/quinquefasciatus_44_1.csv",sep=",")

# %% [markdown]
# ### Home PC

# %%
sound_features_aedes_44_1 = pd.read_csv("/media/homeHDD/Simplon/Formation/Cours/Proj_FinIntensif/Features_CSV/aedes_44_1.csv",sep=",")
sound_features_aedes_48 = pd.read_csv("/media/homeHDD/Simplon/Formation/Cours/Proj_FinIntensif/Features_CSV/Aedes_48.csv",sep=",")
sound_features_culiseta_48 = pd.read_csv("/media/homeHDD/Simplon/Formation/Cours/Proj_FinIntensif/Features_CSV/Culiseta_48.csv",sep=",")
sound_features_mixpipiensquinquefasciatus_48 = pd.read_csv("/media/homeHDD/Simplon/Formation/Cours/Proj_FinIntensif/Features_CSV/MixPipiensQuinquefasciatus_48.csv",sep=",")
sound_features_quinquefasciatus_8 = pd.read_csv("/media/homeHDD/Simplon/Formation/Cours/Proj_FinIntensif/Features_CSV/quinquefasciatus_8.csv",sep=",")
sound_features_quinquefasciatus_44_1 = pd.read_csv("/media/homeHDD/Simplon/Formation/Cours/Proj_FinIntensif/Features_CSV/quinquefasciatus_44_1.csv",sep=",")

# %% [markdown]
# ## Process Column names

# %%
sound_features_aedes_44_1.columns = sound_features_aedes_44_1.columns.str.replace(" ","_")
sound_features_aedes_44_1.rename(columns={"_Zero-Crossing_Rate_":"Zero-Crossing_Rate"},inplace=True)
sound_features_aedes_44_1.columns = sound_features_aedes_44_1.columns.str.replace("-","_")
sound_features_aedes_44_1.columns = sound_features_aedes_44_1.columns.str.replace("#","sharp")

# %%
sound_features_aedes_48.columns = sound_features_aedes_48.columns.str.replace(" ","_")
sound_features_aedes_48.rename(columns={"_Zero-Crossing_Rate_":"Zero-Crossing_Rate"},inplace=True)
sound_features_aedes_48.columns = sound_features_aedes_48.columns.str.replace("-","_")
sound_features_aedes_48.columns = sound_features_aedes_48.columns.str.replace("#","sharp")

# %%
sound_features_culiseta_48.columns = sound_features_culiseta_48.columns.str.replace(" ","_")
sound_features_culiseta_48.rename(columns={"_Zero-Crossing_Rate_":"Zero-Crossing_Rate"},inplace=True)
sound_features_culiseta_48.columns = sound_features_culiseta_48.columns.str.replace("-","_")
sound_features_culiseta_48.columns = sound_features_culiseta_48.columns.str.replace("#","sharp")

# %%
sound_features_mixpipiensquinquefasciatus_48.columns = sound_features_mixpipiensquinquefasciatus_48.columns.str.replace(" ","_")
sound_features_mixpipiensquinquefasciatus_48.rename(columns={"_Zero-Crossing_Rate_":"Zero-Crossing_Rate"},inplace=True)
sound_features_mixpipiensquinquefasciatus_48.columns = sound_features_mixpipiensquinquefasciatus_48.columns.str.replace("-","_")
sound_features_mixpipiensquinquefasciatus_48.columns = sound_features_mixpipiensquinquefasciatus_48.columns.str.replace("#","sharp")

# %%
sound_features_quinquefasciatus_8.columns = sound_features_quinquefasciatus_8.columns.str.replace(" ","_")
sound_features_quinquefasciatus_8.rename(columns={"_Zero-Crossing_Rate_":"Zero-Crossing_Rate"},inplace=True)
sound_features_quinquefasciatus_8.columns = sound_features_quinquefasciatus_8.columns.str.replace("-","_")
sound_features_quinquefasciatus_8.columns = sound_features_quinquefasciatus_8.columns.str.replace("#","sharp")

# %%
sound_features_quinquefasciatus_44_1.columns = sound_features_quinquefasciatus_44_1.columns.str.replace(" ","_")
sound_features_quinquefasciatus_44_1.rename(columns={"_Zero-Crossing_Rate_":"Zero-Crossing_Rate"},inplace=True)
sound_features_quinquefasciatus_44_1.columns = sound_features_quinquefasciatus_44_1.columns.str.replace("-","_")
sound_features_quinquefasciatus_44_1.columns = sound_features_quinquefasciatus_44_1.columns.str.replace("#","sharp")

# %% [markdown]
# ## Check for missing values

# %%
sound_features_aedes_44_1.isna().sum()
# Out:
# Filename                        0
# Zero-Crossing_Rate              0
# Short-Term_Energy               0
# Short-Term_Entropy_of_Energy    0
# Spectral_Centroid               0
# Spectral_Spread                 0
# Spectral_Entropy                0
# Spectral_Flux                   0
# Spectral_Roll_off               0
# MFCC_1                          0
# MFCC_2                          0
# MFCC_3                          0
# MFCC_4                          0
# MFCC_5                          0
# MFCC_6                          0
# MFCC_7                          0
# MFCC_8                          0
# MFCC_9                          0
# MFCC_10                         0
# MFCC_11                         0
# MFCC_12                         0
# MFCC_13                         0
# Chroma_Vector_A                 0
# Chroma_Vector_A#                0
# Chroma_Vector_B                 0
# Chroma_Vector_C                 0
# Chroma_Vector_C#                0
# ...

# %%
sound_features_aedes_48.isna().sum()
# Out:
# Filename                        0
# Zero-Crossing_Rate              0
# Short-Term_Energy               0
# Short-Term_Entropy_of_Energy    0
# Spectral_Centroid               0
# Spectral_Spread                 0
# Spectral_Entropy                0
# Spectral_Flux                   0
# Spectral_Roll_off               0
# MFCC_1                          0
# MFCC_2                          0
# MFCC_3                          0
# MFCC_4                          0
# MFCC_5                          0
# MFCC_6                          0
# MFCC_7                          0
# MFCC_8                          0
# MFCC_9                          0
# MFCC_10                         0
# MFCC_11                         0
# MFCC_12                         0
# MFCC_13                         0
# Chroma_Vector_A                 0
# Chroma_Vector_A#                0
# Chroma_Vector_B                 0
# Chroma_Vector_C                 0
# Chroma_Vector_C#                0
# ...

# %%
sound_features_culiseta_48.isna().sum()
# Out:
# Filename                        0
# Zero-Crossing_Rate              1
# Short-Term_Energy               1
# Short-Term_Entropy_of_Energy    1
# Spectral_Centroid               1
# Spectral_Spread                 1
# Spectral_Entropy                1
# Spectral_Flux                   1
# Spectral_Roll_off               1
# MFCC_1                          1
# MFCC_2                          1
# MFCC_3                          1
# MFCC_4                          1
# MFCC_5                          1
# MFCC_6                          1
# MFCC_7                          1
# MFCC_8                          1
# MFCC_9                          1
# MFCC_10                         1
# MFCC_11                         1
# MFCC_12                         1
# MFCC_13                         1
# Chroma_Vector_A                 1
# Chroma_Vector_A#                1
# Chroma_Vector_B                 1
# Chroma_Vector_C                 1
# Chroma_Vector_C#                1
# ...

# %%
sound_features_mixpipiensquinquefasciatus_48.isna().sum()
# Out:
# Filename                        0
# Zero-Crossing_Rate              0
# Short-Term_Energy               0
# Short-Term_Entropy_of_Energy    0
# Spectral_Centroid               0
# Spectral_Spread                 0
# Spectral_Entropy                0
# Spectral_Flux                   0
# Spectral_Roll_off               0
# MFCC_1                          0
# MFCC_2                          0
# MFCC_3                          0
# MFCC_4                          0
# MFCC_5                          0
# MFCC_6                          0
# MFCC_7                          0
# MFCC_8                          0
# MFCC_9                          0
# MFCC_10                         0
# MFCC_11                         0
# MFCC_12                         0
# MFCC_13                         0
# Chroma_Vector_A                 0
# Chroma_Vector_A#                0
# Chroma_Vector_B                 0
# Chroma_Vector_C                 0
# Chroma_Vector_C#                0
# ...

# %%
sound_features_quinquefasciatus_8.isna().sum()
# Out:
# Filename                         0
# Zero-Crossing_Rate              33
# Short-Term_Energy               33
# Short-Term_Entropy_of_Energy    33
# Spectral_Centroid               33
# Spectral_Spread                 33
# Spectral_Entropy                33
# Spectral_Flux                   33
# Spectral_Roll_off               33
# MFCC_1                          33
# MFCC_2                          33
# MFCC_3                          33
# MFCC_4                          33
# MFCC_5                          33
# MFCC_6                          33
# MFCC_7                          33
# MFCC_8                          33
# MFCC_9                          33
# MFCC_10                         33
# MFCC_11                         33
# MFCC_12                         33
# MFCC_13                         33
# Chroma_Vector_A                 33
# Chroma_Vector_A#                33
# Chroma_Vector_B                 33
# Chroma_Vector_C                 33
# Chroma_Vector_C#                33
# ...

# %%
sound_features_quinquefasciatus_44_1.isna().sum()
# Out:
# Filename                        0
# Zero-Crossing_Rate              0
# Short-Term_Energy               0
# Short-Term_Entropy_of_Energy    0
# Spectral_Centroid               0
# Spectral_Spread                 0
# Spectral_Entropy                0
# Spectral_Flux                   0
# Spectral_Roll_off               0
# MFCC_1                          0
# MFCC_2                          0
# MFCC_3                          0
# MFCC_4                          0
# MFCC_5                          0
# MFCC_6                          0
# MFCC_7                          0
# MFCC_8                          0
# MFCC_9                          0
# MFCC_10                         0
# MFCC_11                         0
# MFCC_12                         0
# MFCC_13                         0
# Chroma_Vector_A                 0
# Chroma_Vector_A#                0
# Chroma_Vector_B                 0
# Chroma_Vector_C                 0
# Chroma_Vector_C#                0
# ...

# %% [markdown]
# Rows with missing values are missing all columns, so dropping them is a sensible option.

# %%
sound_features_culiseta_48.dropna(inplace=True)
sound_features_quinquefasciatus_8.dropna(inplace=True)

# %% [markdown]
# ## Add sampling rate and species column

# %%
sound_features_aedes_44_1 
sound_features_aedes_48 
sound_features_culiseta_48 
sound_features_mixpipiensquinquefasciatus_48 
sound_features_quinquefasciatus_8 
sound_features_quinquefasciatus_44_1

# %%
sound_features_aedes_44_1
# Out:
#           Filename  Zero-Crossing_Rate  Short-Term_Energy  \
# 0    aedes_116.wav            0.085844           0.051013
# 1    aedes_118.wav            0.141878           0.038597
# 2    aedes_120.wav            0.117332           0.015005
# 3    aedes_122.wav            0.088249           0.053398
# 4    aedes_135.wav            0.148140           0.029196
# ..             ...                 ...                ...
# 84   aedes_630.wav            0.098321           0.024417
# 85   aedes_632.wav            0.075363           0.071136
# 86   aedes_633.wav            0.059437           0.092476
# 87   aedes_641.wav            0.112886           0.057520
# 88   aedes_645.wav            0.111343           0.064292
#
#     Short-Term_Entropy_of_Energy  Spectral_Centroid  Spectral_Spread  \
# 0                       3.261537           0.209399         0.230026
# 1                       3.152052           0.238570         0.213609
# ...

# %%
sound_features_aedes_44_1.insert(1,"Species","Aedes_Aegypti")
sound_features_aedes_44_1.insert(2,"Sampling_Rate",44.1)

# %%
sound_features_aedes_48.insert(1,"Species","Aedes_Aegypti")
sound_features_aedes_48.insert(2,"Sampling_Rate",48)

# %%
sound_features_culiseta_48.insert(1,"Species","Culiseta")
sound_features_culiseta_48.insert(2,"Sampling_Rate",48)

# %%
sound_features_mixpipiensquinquefasciatus_48.insert(1,"Species","Culex")
sound_features_mixpipiensquinquefasciatus_48.insert(2,"Sampling_Rate",48)

# %%
sound_features_quinquefasciatus_8.insert(1,"Species","Culex")
sound_features_quinquefasciatus_8.insert(2,"Sampling_Rate",8)

# %%
sound_features_quinquefasciatus_44_1.insert(1,"Species","Culex")
sound_features_quinquefasciatus_44_1.insert(2,"Sampling_Rate",44.1)

# %% [markdown]
# ## Export feature matrix

# %%
mosquito_featureset_original = pd.concat([sound_features_aedes_44_1,sound_features_aedes_48,sound_features_culiseta_48,sound_features_mixpipiensquinquefasciatus_48,sound_features_quinquefasciatus_44_1,sound_features_quinquefasciatus_8])

# %%
mosquito_featureset_original
# Out:
#                      Filename        Species  Sampling_Rate  \
# 0               aedes_116.wav  Aedes_Aegypti           44.1
# 1               aedes_118.wav  Aedes_Aegypti           44.1
# 2               aedes_120.wav  Aedes_Aegypti           44.1
# 3               aedes_122.wav  Aedes_Aegypti           44.1
# 4               aedes_135.wav  Aedes_Aegypti           44.1
# ..                        ...            ...            ...
# 862   quinquefasciatus_95.wav          Culex            8.0
# 863   quinquefasciatus_96.wav          Culex            8.0
# 864   quinquefasciatus_97.wav          Culex            8.0
# 865   quinquefasciatus_98.wav          Culex            8.0
# 866   quinquefasciatus_99.wav          Culex            8.0
#
#      Zero_Crossing_Rate  Short_Term_Energy  Short_Term_Entropy_of_Energy  \
# 0              0.085844           0.051013                      3.261537
# 1              0.141878           0.038597                      3.152052
# ...

# %%
mosquito_featureset_original.loc[(mosquito_featureset_original["Species"]=="Culex")&(mosquito_featureset_original["Sampling_Rate"]==8)]
# Out:
#                       Filename Species  Sampling_Rate  Zero_Crossing_Rate  \
# 0       quinquefasciatus_0.wav   Culex            8.0            0.168831
# 1       quinquefasciatus_1.wav   Culex            8.0            0.124174
# 2      quinquefasciatus_10.wav   Culex            8.0            0.052404
# 3     quinquefasciatus_100.wav   Culex            8.0            0.121212
# 5     quinquefasciatus_102.wav   Culex            8.0            0.155844
# ..                         ...     ...            ...                 ...
# 862    quinquefasciatus_95.wav   Culex            8.0            0.149692
# 863    quinquefasciatus_96.wav   Culex            8.0            0.115060
# 864    quinquefasciatus_97.wav   Culex            8.0            0.142174
# 865    quinquefasciatus_98.wav   Culex            8.0            0.069720
# 866    quinquefasciatus_99.wav   Culex            8.0            0.220779
#
#      Short_Term_Energy  Short_Term_Entropy_of_Energy  Spectral_Centroid  \
# ...

# %%
mosquito_featureset_original.columns
# Out:
# Index(['Filename', 'Species', 'Sampling_Rate', 'Zero_Crossing_Rate',
#        'Short_Term_Energy', 'Short_Term_Entropy_of_Energy',
#        'Spectral_Centroid', 'Spectral_Spread', 'Spectral_Entropy',
#        'Spectral_Flux', 'Spectral_Roll_off', 'MFCC_1', 'MFCC_2', 'MFCC_3',
#        'MFCC_4', 'MFCC_5', 'MFCC_6', 'MFCC_7', 'MFCC_8', 'MFCC_9', 'MFCC_10',
#        'MFCC_11', 'MFCC_12', 'MFCC_13', 'Chroma_Vector_A',
#        'Chroma_Vector_Asharp', 'Chroma_Vector_B', 'Chroma_Vector_C',
#        'Chroma_Vector_Csharp', 'Chroma_Vector_D', 'Chroma_Vector_Dsharp',
#        'Chroma_Vector_E', 'Chroma_Vector_F', 'Chroma_Vector_Fsharp',
#        'Chroma_Vector_G', 'Chroma_Vector_Gsharp', 'Chroma_Deviation'],
#       dtype='object')

# %% [markdown]
# ### Laptop

# %%
mosquito_featureset_original.to_csv("/home/flo/Documents/Simplon/Formation/Cours/Proj_FinIntensif/Features_CSV/mosquito_featureset_original.csv",index=False)

# %% [markdown]
# ### Home PC

# %%
mosquito_featureset_original.to_csv("/media/homeHDD/Simplon/Formation/Cours/Proj_FinIntensif/Features_CSV/mosquito_featureset_original.csv",index=False)
